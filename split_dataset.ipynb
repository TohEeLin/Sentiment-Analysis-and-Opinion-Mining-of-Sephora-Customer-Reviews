# %% [markdown]
# <a href="https://colab.research.google.com/github/EmilyPhang/Social-Media-Computing-Project-Sentiment-Analysis-of-Sephora-Reviews/blob/main/split_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# Load the data from CSV files
df = pd.read_csv("/content/drive/MyDrive/Dataset/full_sephora_reviews_classification.csv")
df.head()
# Out:
#      author_id  rating  is_recommended  helpfulness  total_feedback_count  \
# 0   5972581853       5             1.0         0.75                   4.0
# 1   5806637205       5             1.0         1.00                   2.0
# 2   6637028158       5             1.0         1.00                   5.0
# 3  23890184577       3             1.0         1.00                   1.0
# 4   5313908074       4             1.0         1.00                   2.0
#
#    total_neg_feedback_count  total_pos_feedback_count submission_time  \
# 0                       1.0                       3.0      2018-12-21
# 1                       0.0                       2.0      2021-07-14
# 2                       0.0                       5.0      2023-03-08
# 3                       0.0                       1.0      2021-10-10
# 4                       0.0                       2.0      2023-02-07
#
#                                          review_text  skin_tone  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# author_id                   0
# rating                      0
# is_recommended              0
# helpfulness                 0
# total_feedback_count        0
# total_neg_feedback_count    0
# total_pos_feedback_count    0
# submission_time             0
# review_text                 0
# skin_tone                   0
# eye_color                   0
# skin_type                   0
# hair_color                  0
# product_id                  0
# product_name                0
# brand_name                  0
# price_usd                   0
# brand_id                    0
# child_count                 0
# highlights                  0
# ingredients                 0
# limited_edition             0
# loves_count                 0
# new                         0
# online_only                 0
# out_of_stock                0
# primary_category            0
# reviews                     0
# secondary_category          0
# sephora_exclusive           0
# size                        0
# ...

# %%
df = df[['cleaned_review', 'sentiment_label']]

# %%
# First split: train (60%) and temp (40%)
train_df, temp_df = train_test_split(df, test_size=0.4, stratify=df['sentiment_label'], random_state=42)

# Second split: val (20%) and test (20%)
val_df, test_df = train_test_split(temp_df, test_size=0.5, stratify=temp_df['sentiment_label'], random_state=42)

# %%
print("Train:", len(train_df))
print("Validation:", len(val_df))
print("Test:", len(test_df))
# Out:
# Train: 4680
# Validation: 1560
# Test: 1560

# %%
print("Train label distribution:")
print(train_df['sentiment_label'].value_counts())

print("\nValidation label distribution:")
print(val_df['sentiment_label'].value_counts())

print("\nTest label distribution:")
print(test_df['sentiment_label'].value_counts())
# Out:
# Train label distribution:
# sentiment_label
# negative    1560
# neutral     1560
# positive    1560
# Name: count, dtype: int64
#
# Validation label distribution:
# sentiment_label
# positive    520
# neutral     520
# negative    520
# Name: count, dtype: int64
#
# Test label distribution:
# sentiment_label
# negative    520
# positive    520
# neutral     520
# Name: count, dtype: int64

# %%
# Save to CSV
train_df.to_csv("/content/drive/MyDrive/Dataset/train.csv", index=False)
val_df.to_csv("/content/drive/MyDrive/Dataset/val.csv", index=False)
test_df.to_csv("/content/drive/MyDrive/Dataset/test.csv", index=False)
